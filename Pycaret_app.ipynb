# %%
import pandas as pd
data = pd.read_excel('Book1.xlsx')

# %%
from pycaret.regression import *

# %%
s = setup(data, target='CPL')
# Out:
# <style  type="text/css" >
# </style><table id="T_08b196e4_8dee_11eb_bd53_089798b72aa7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_08b196e4_8dee_11eb_bd53_089798b72aa7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_08b196e4_8dee_11eb_bd53_089798b72aa7row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_08b196e4_8dee_11eb_bd53_089798b72aa7row0_col1" class="data row0 col1" >1038</td>
#             </tr>
#             <tr>
#                         <th id="T_08b196e4_8dee_11eb_bd53_089798b72aa7level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_08b196e4_8dee_11eb_bd53_089798b72aa7row1_col0" class="data row1 col0" >Target</td>
# ...

# %%
models()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d02dfb14cc9e> in <module>
# ----> 1 models()
#
# ~\anaconda3\envs\appenv\lib\site-packages\pycaret\regression.py in models(type, internal, raise_errors)
#    2045     """
#    2046     return pycaret.internal.tabular.models(
# -> 2047         type=type, internal=internal, raise_errors=raise_errors
#    2048     )
#    2049
#
# ~\anaconda3\envs\appenv\lib\site-packages\pycaret\internal\tabular.py in models(type, internal, raise_errors)
#    9209         )
#    9210
# -> 9211     logger.info(f"gpu_param set to {gpu_param}")
#    9212
#    9213     if _ml_usecase == MLUsecase.CLASSIFICATION:
#
# NameError: name 'logger' is not defined

# %%
compare_models()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9ff5ccfe3077> in <module>
# ----> 1 compare_models()
#
# ~\anaconda3\envs\appenv\lib\site-packages\pycaret\regression.py in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, verbose)
#     775         fit_kwargs=fit_kwargs,
#     776         groups=groups,
# --> 777         verbose=verbose,
#     778     )
#     779
#
# ~\anaconda3\envs\appenv\lib\site-packages\pycaret\internal\tabular.py in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, verbose, display)
#    1930
#    1931     # checking error for exclude (string)
# -> 1932     available_estimators = _all_models
#    1933
#    1934     if exclude != None:
#
# NameError: name '_all_models' is not defined

# %%
s1 = setup(data, target='CPL', normalize=True, normalize_method='minmax', polynomial_features=True)
# Out:
# <style  type="text/css" >
# #T_57ddd782_9058_11eb_ba1d_089798b72aa7row27_col1,#T_57ddd782_9058_11eb_ba1d_089798b72aa7row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_57ddd782_9058_11eb_ba1d_089798b72aa7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_57ddd782_9058_11eb_ba1d_089798b72aa7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_57ddd782_9058_11eb_ba1d_089798b72aa7row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_57ddd782_9058_11eb_ba1d_089798b72aa7row0_col1" class="data row0 col1" >5103</td>
#             </tr>
#             <tr>
#                         <th id="T_57ddd782_9058_11eb_ba1d_089798b72aa7level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
best=compare_models()
# Out:
# <style  type="text/css" >
#     #T_6984c3e2_9058_11eb_96d4_089798b72aa7 th {
#           text-align: left;
# ...

# %%
# Model training and validation

mod = create_model(best)
# Out:
# <style  type="text/css" >
# #T_745c874a_9058_11eb_9199_089798b72aa7row10_col0,#T_745c874a_9058_11eb_9199_089798b72aa7row10_col1,#T_745c874a_9058_11eb_9199_089798b72aa7row10_col2,#T_745c874a_9058_11eb_9199_089798b72aa7row10_col3,#T_745c874a_9058_11eb_9199_089798b72aa7row10_col4,#T_745c874a_9058_11eb_9199_089798b72aa7row10_col5{
#             background:  yellow;
#         }</style><table id="T_745c874a_9058_11eb_9199_089798b72aa7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_745c874a_9058_11eb_9199_089798b72aa7level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
# Plot residuals of trained model
plot_model(best, plot='residuals')

# %%
mod_tuned = tune_model(mod)
# Out:
# <style  type="text/css" >
# #T_89372bd2_9058_11eb_877c_089798b72aa7row10_col0,#T_89372bd2_9058_11eb_877c_089798b72aa7row10_col1,#T_89372bd2_9058_11eb_877c_089798b72aa7row10_col2,#T_89372bd2_9058_11eb_877c_089798b72aa7row10_col3,#T_89372bd2_9058_11eb_877c_089798b72aa7row10_col4,#T_89372bd2_9058_11eb_877c_089798b72aa7row10_col5{
#             background:  yellow;
#         }</style><table id="T_89372bd2_9058_11eb_877c_089798b72aa7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_89372bd2_9058_11eb_877c_089798b72aa7level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
plot_model(mod_tuned)

# %%
# Save transformation pipeline and model
save_model(mod_tuned, model_name ='C:/Users/nikhi/Desktop/ME/College_stuff/ABB_Internship/Sample Project/Cross validation and RFR/Real_Deal/sampleapp')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=['Number ID'],
#                                        ml_usecase='regression',
#                                        numerical_features=[], target='CPL',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_st...
#                  ('dummy', Dummify(target='CPL')),
#                  ('fix_perfect', Remove_100(target='CPL')),
#                  ('clean_names', Clean_Colum_Names()),
# ...
