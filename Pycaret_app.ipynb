# %%
import pandas as pd
data = pd.read_excel('Book1.xlsx')

# %%
from pycaret.regression import *

# %%
s = setup(data, target='CPL')
# Out:
# <style  type="text/css" >
# </style><table id="T_cf6ae20c_9211_11eb_846f_089798b72aa7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cf6ae20c_9211_11eb_846f_089798b72aa7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cf6ae20c_9211_11eb_846f_089798b72aa7row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_cf6ae20c_9211_11eb_846f_089798b72aa7row0_col1" class="data row0 col1" >5368</td>
#             </tr>
#             <tr>
#                         <th id="T_cf6ae20c_9211_11eb_846f_089798b72aa7level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cf6ae20c_9211_11eb_846f_089798b72aa7row1_col0" class="data row1 col0" >Target</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_dc16c748_9211_11eb_8ce1_089798b72aa7 th {
#           text-align: left;
# ...

# %%
s1 = setup(data, target='CPL', numeric_features=['LdTime'], normalize=True, polynomial_features=True, trigonometry_features=True, imputation_type='iterative')
# Out:
# <style  type="text/css" >
# #T_987b0578_9213_11eb_9a85_089798b72aa7row27_col1,#T_987b0578_9213_11eb_9a85_089798b72aa7row44_col1,#T_987b0578_9213_11eb_9a85_089798b72aa7row46_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_987b0578_9213_11eb_9a85_089798b72aa7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_987b0578_9213_11eb_9a85_089798b72aa7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_987b0578_9213_11eb_9a85_089798b72aa7row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_987b0578_9213_11eb_9a85_089798b72aa7row0_col1" class="data row0 col1" >7575</td>
#             </tr>
#             <tr>
# ...

# %%
best=compare_models()
# Out:
# <style  type="text/css" >
#     #T_a51bfc70_9213_11eb_a378_089798b72aa7 th {
#           text-align: left;
# ...

# %%
# Model training and validation

mod = create_model(best)
# Out:
# <style  type="text/css" >
# #T_a7c7fdee_9213_11eb_98e4_089798b72aa7row10_col0,#T_a7c7fdee_9213_11eb_98e4_089798b72aa7row10_col1,#T_a7c7fdee_9213_11eb_98e4_089798b72aa7row10_col2,#T_a7c7fdee_9213_11eb_98e4_089798b72aa7row10_col3,#T_a7c7fdee_9213_11eb_98e4_089798b72aa7row10_col4,#T_a7c7fdee_9213_11eb_98e4_089798b72aa7row10_col5{
#             background:  yellow;
#         }</style><table id="T_a7c7fdee_9213_11eb_98e4_089798b72aa7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a7c7fdee_9213_11eb_98e4_089798b72aa7level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
# Plot residuals of trained model
plot_model(best, plot='residuals')

# %%
mod_tuned = tune_model(mod)
# Out:
# <style  type="text/css" >
# #T_ac47bc98_9213_11eb_9cef_089798b72aa7row10_col0,#T_ac47bc98_9213_11eb_9cef_089798b72aa7row10_col1,#T_ac47bc98_9213_11eb_9cef_089798b72aa7row10_col2,#T_ac47bc98_9213_11eb_9cef_089798b72aa7row10_col3,#T_ac47bc98_9213_11eb_9cef_089798b72aa7row10_col4,#T_ac47bc98_9213_11eb_9cef_089798b72aa7row10_col5{
#             background:  yellow;
#         }</style><table id="T_ac47bc98_9213_11eb_9cef_089798b72aa7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ac47bc98_9213_11eb_9cef_089798b72aa7level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
plot_model(mod_tuned)

# %%
# Save transformation pipeline and model
save_model(mod_tuned, model_name ='C:/Users/nikhi/Desktop/ME/College_stuff/ABB_Internship/Sample Project/Cross validation and RFR/Real_Deal/Sampleapp/sampleapp')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=['Number ID'],
#                                        ml_usecase='regression',
#                                        numerical_features=['LdTime'],
#                                        target='CPL', time_features=[])),
#                  ('imputer',
#                   Iterative_Imputer(add_indicator=False,
#                                     classifier=LGBMClassifier(boosting_type='gbdt',
#                                                               class_weight=None,
#                                                               colsa...
#                  ('dummy', Dummify(target='CPL')),
#                  ('fix_perfect', Remove_100(target='CPL')),
# ...
